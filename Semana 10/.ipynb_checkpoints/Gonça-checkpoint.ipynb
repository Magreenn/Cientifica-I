# %% [markdown]
# ![CC-BY-SA](https://mirrors.creativecommons.org/presskit/buttons/88x31/svg/by-sa.svg)
#
#
# This notebook was created by [Bernardo Freitas Paulo da Costa](http://www.im.ufrj.br/bernardofpc),
# and Pedro Angelo Medeiros Fonini
# and is licensed under Creative Commons BY-SA.

# %% [markdown]
# Antes de enviar este Teste, verifique que tudo está funcionando como esperado.
# Por exemplo, **rode o código inteiro, do zero**.
# Para isso, vá no menu, escolha _Kernel_, depois _Restart & Run All_.
#
# Verifique, também, que você respondeu todas as questões:
# * as questões de código têm `YOUR CODE HERE` (e você pode apagar o `raise NotImplemented` ao incluir sua resposta)
# * as questões discursivas têm "YOUR ANSWER HERE".

# %% [markdown]
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from fractions import Fraction

# %% [markdown]
# # Pivôs e eliminação
#
# ## Questão 1: Eliminação pura
#
# Comece escrevendo um código de resolução de sistemas lineares que não permuta linhas nem colunas

# %%
def solve(A,b,fracoes=False):
    """Resolve o sistema  Ax = b,  sem reordenar linhas ou colunas
    Saída pode ser em float (padrão) ou em frações"""
    if fracoes == True:
        AF = np.array([[Fraction(aij) for aij in ai] for ai in A])
        BF = np.array([Fraction(bi) for bi in b])
    else:
        AF = np.array(A)
        BF = np.array(b)
        
    nlim = len(b)
    for i in range(nlim):
        for k in range(1+i,nlim):
            coef = (AF[k,i]/AF[i,i])
            AF[k:k+1] = AF[k:k+1] - AF[i:i+1]*coef
            AF[k,i] = 0
            BF[k] = BF[k] - BF[i]*coef 
    resol = []
    resol.append(BF[nlim-1]/AF[nlim-1,nlim-1])
    for i in range(nlim-1):
        x_i = (BF[nlim-i-2] - np.sum(AF[nlim-i-2,nlim-i-1:nlim]*np.flip(resol,0)))/AF[nlim-i-2,nlim-i-2]
        resol.append(x_i)
    
    return np.flip(resol,0)

# %%
#np.random.seed(1)

#M = np.vander(np.arange(10, dtype=np.float64), increasing=True)
#b = np.random.rand(10)
#M  = np.array([[1,1,1],[2,1,-1],[2,2,1]])
#b = np.array([1,0,1])
#x1 = solve(M,b,fracoes=False)#
#b1 = M @ x1
#print(x1)
#for i in range(len(b)):
#    print(f"A diferença entre B e b1 é de {abs(b[i]-b1[i]): 30.10f}, sendo b {b[i]: 5.5f}")

# %% [markdown]
# Vejamos que está funcionando, dando resultados semelhantes ao que vimos em aula:

# %%
np.random.seed(1)

M = np.vander(np.arange(11, dtype=np.float64), increasing=True)
b = np.random.rand(11)
x1 = solve(M,b)

b1 = M @ x1
assert b1[0] == b[0]
assert np.isclose(b1[10], b[10])
assert np.linalg.norm(b1 - b) < 1e-8

# %%
np.random.seed(2)

M = np.vander(np.arange(51, dtype=np.float64), increasing=True)
b = np.random.rand(51)
x1 = solve(M,b)

b1 = M @ x1
assert b1[0] == b[0]
assert np.isclose(b1[4], b[4])
assert np.abs(b1[-3] - b[-3]) > 1e10

# %% [markdown]
# Agora, resolva 100 sistemas $51 \times 51$, com a mesma matriz, mas com diferentes valores de $b$.
# Mostre, num mesmo gráfico,
# * o erro absoluto médio
# * o menor erro absoluto
# * o maior erro absoluto
#
# para cada equação do sistema $Ax = b$.

# %%
# %%time 

num_sys = 100
num_m = 51


M = np.vander(np.arange(num_m, dtype=np.float64), increasing=True)
#M = np.random.randn(num_m,num_m)

acc_err_sys = np.zeros(num_sys)
max_err_sys = np.zeros(num_sys)
min_err_sys = np.ones(num_sys)


for sistema in range(num_sys):
    #acc_err = np.zeros(num_m)
    #max_err = np.zeros(num_m)
    #min_err = np.ones(num_m) * np.inf
    
    np.random.seed(sistema)
    x_true = np.random.rand(num_m)
    b = M @ x_true
    #print(b)
    x_solve = solve(M,b)
    
    for i in range(num_m-1,num_m):
        aux= np.zeros(num_m)
        for j in range(num_m-1,num_m):
            err_aij = (np.abs(x_solve[j]-x_true[j]))
            aux[j] = err_aij
            
        #acc_err[i] = aux.mean()
        #max_err[i] = aux.max()
        #min_err[i] = aux.min()
        
    acc_err_sys[sistema] = aux.mean()
    max_err_sys[sistema] = aux.max()
    min_err_sys[sistema] = aux.min()
# Out:
# Wall time: 1.04 s

# %%
plt.figure(figsize=(15,8))
ax = plt.gca()
ax.semilogy(acc_err_sys,label="Erro Médio");
ax.semilogy(max_err_sys,label="Erro Máximo");
ax.semilogy(min_err_sys,label="Erro Mínimo");
ax.tick_params(labelsize=12)
ax.set_title(f"Erros na {num_m}ª equação nos {num_sys} sistemas",fontdict={'fontsize':15})
ax.set_xlabel("Equações")
ax.set_ylabel("Erro")
ax.legend();

# %%
assert ax.title.get_text() != ""
assert len(ax.lines) == 3
assert len(ax.get_legend().get_texts()) == 3

# %%
ax = None

# %% [markdown]
# O que você observa?

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Questão 2: Permutando linhas
#
# Re-escreva o código de eliminação para encontrar, a cada coluna, a linha que tem o maior pivô (em valor absoluto).
#
# Observações:
# * Não será necessário alterar a parte de substituição;
# * Mas lembre-se de também alterar as linhas de `b`.
# * E cuidado ao mudar as linhas de uma matriz: use `np.copy` para copiar linhas, e `[:]` para substituir todos os valores de um array.

# %%
def solve_pivot_lines(A,b,fracoes = False):
    """Resolve o sistema  Ax = b,  reordenando apenas linhas, se necessário."""
    
    nlim = len(b)
    if fracoes == True:
        AF = np.array([[Fraction(aij) for aij in ai] for ai in A])
        BF = np.array([Fraction(bi) for bi in b])
    else:
        AF = np.array(A,dtype=np.float64)
        BF = np.array(b,dtype=np.float64)
        AF = np.insert(AF,nlim,BF,axis=1)
        
    
    
    
    
    
    for i in range(nlim):
        max_col = np.max(np.abs(AF[i:nlim,i]))
        if max_col != np.abs(AF[i,i]):
            col = list(np.abs(AF[i:nlim+1,i]))
            linha_a = np.copy(AF[i:i+1, :])
            indice = col.index(max_col)+i
            AF[i:i+1] = np.copy(AF[indice:indice+1, : ])
            AF[indice:indice+1] = linha_a
            
            
            
        for k in range(1+i,nlim):
            coef = (AF[k,i]/AF[i,i])
            AF[k:k+1] = AF[k:k+1] - AF[i:i+1]*coef
            
    BF = AF[0:nlim,nlim]
    AF = np.delete(AF,nlim,1)
    
    resol = []
    resol.append(BF[nlim-1]/AF[nlim-1,nlim-1])
    for i in range(nlim-1):
        x_i = (BF[nlim-i-2] - np.sum(AF[nlim-i-2,nlim-i-1:nlim]*np.flip(resol,0)))/AF[nlim-i-2,nlim-i-2]
        resol.append(x_i)
    
    return np.flip(resol,0)

# %%
#np.random.seed(3)

#M = np.vander(np.arange(5, dtype=np.float64), increasing=True)
#b = np.random.rand(5)
#x1 = solve_pivot_lines(M,b)
#print(BF)

#b1 = M @ x1

#print(b1[0],b[0])

# %% [markdown]
# Novamente, testando que está tudo ok:

# %%
np.random.seed(3)

M = np.vander(np.arange(11, dtype=np.float64), increasing=True)
b = np.random.rand(11)
x1 = solve_pivot_lines(M,b)

b1 = M @ x1
assert b1[0] == b[0]
assert np.isclose(b1[10], b[10])
assert np.linalg.norm(b1 - b) < 1e-8

# %%
np.random.seed(4)

M = np.vander(np.arange(51, dtype=np.float64), increasing=True)
b = np.random.rand(51)
x1 = solve_pivot_lines(M,b)

b1 = M @ x1
assert b1[0] == b[0]
assert np.allclose(b1, b, atol=30.0)
assert np.linalg.norm(b - b1) > 10

# %% [markdown]
# Estes testes são (ligeiramente) diferentes dos testes para `solve`, que não realizava permutação de linhas.
# Explique porque estas mudanças
# 1. são necessárias; e
# 2. fazem sentido.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ### Mais gráficos
#
# Repita a análise, com 100 sistemas $51 \times 51$.

# %%
# %%time

M = np.vander(range(51), increasing=True).astype(np.float64)

num_sys = 100
num_m = 51


acc_err_pivot_sys = np.zeros(num_sys)
max_err_pivot_sys = np.zeros(num_sys)
min_err_pivot_sys = np.ones(num_sys)


for sistema in range(num_sys):
    
    np.random.seed(sistema)
    b = np.random.rand(num_m)
    x_solve = solve(M,b)
    b_solve = M @ x_solve
    
    for i in range(num_m):
        aux= np.zeros(num_m)
            err_aij = (np.abs(b_solve[j]-b_true[j]))
            aux[j] = err_aij
            
        #acc_err[i] = aux.mean()
        #max_err[i] = aux.max()
        #min_err[i] = aux.min()
        
    acc_err_pivot_sys[sistema] = aux.mean()
    max_err_pivot_sys[sistema] = aux.max()
    min_err_pivot_sys[sistema] = aux.min()
# Out:
# Wall time: 984 ms

# %%
plt.figure(figsize=(15,8))
ax = plt.gca()
ax.semilogy(acc_err_pivot_sys,label="Erro Médio");
ax.semilogy(max_err_pivot_sys,label="Erro Máximo");
ax.semilogy(min_err_pivot_sys,label="Erro Mínimo");
ax.tick_params(labelsize=12)
ax.set_title(f"Erros na {num_m}ª equação nos {num_sys} sistemas",fontdict={'fontsize':15})
ax.legend();

# %%
assert ax.title.get_text() != ""
assert len(ax.lines) == 3
assert len(ax.get_legend().get_texts()) == 3

# %%
ax = None

# %% [markdown]
# ## Questão 3: Quantidade de trocas de linhas
#
# Agora, adapte seu código de eliminação para contar (e apenas contar) o número de permutações de linhas efetuadas.
# Observe que esta quantidade é independente do valor de $b$.

# %%
def count_row_xchg(A):
    """Conta o número de permutações de linhas efetuadas para resolver o sistema  Ax = b"""
    nlim = len(A)

    AF = np.array(A,dtype=np.float64)
        
    
    
    
    
    count = 0
    for i in range(nlim):
        max_col = np.max(np.abs(AF[i:nlim,i]))
        if max_col != np.abs(AF[i,i]):
            col = list(np.abs(AF[i:nlim+1,i]))
            linha_a = np.copy(AF[i:i+1, :])
            indice = col.index(max_col)+i
            AF[i:i+1] = np.copy(AF[indice:indice+1, : ])
            AF[indice:indice+1] = linha_a
            count += 1
        
        for k in range(1+i,nlim):
            coef = (AF[k,i]/AF[i,i])
            AF[k:k+1] = AF[k:k+1] - AF[i:i+1]*coef
    
    return count

# %%
M = np.vander(np.arange(11, dtype=np.float64), increasing=True)
assert count_row_xchg(M) == 7

M = np.vander(np.arange(51, dtype=np.float64), increasing=True)
assert count_row_xchg(M) == 44

# %% [markdown]
# Quantas permutações de linha são realizadas
# - para as matrizes de Vandermonde assimétricas
# - para as matrizes de Vandermonde simétricas
# - para matrizes gaussianas
#
# em função de $n$?
#
# Faça um gráfico.

# %%
# %%time

# Contas
# YOUR CODE HERE
raise NotImplementedError()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <timed exec> in <module>
#
# NotImplementedError:

# %%
# YOUR CODE HERE
raise NotImplementedError()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-22-15b94d1fa268> in <module>
#       1 # YOUR CODE HERE
# ----> 2 raise NotImplementedError()
#
# NotImplementedError:

# %% [markdown]
# O que você percebe?

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Questão 4 (Bônus): comparando com o `numpy`
#
# Faça o gráfico dos erros para o `np.linalg.solve`.  Como este se comporta, em comparação com o método de troca de linhas?

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# YOUR ANSWER HERE
